# %%
import pandas as pd 

df = pd.read_csv("data-faskes-2019.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29157 entries, 0 to 29156
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NoLink         29157 non-null  int64
#  1   Provinsi       29157 non-null  object
#  2   KotaKab        29157 non-null  object
#  3   Link           29157 non-null  object
#  4   TipeFaskes     29157 non-null  object
#  5   No             29157 non-null  object
#  6   KodeFaskes     29157 non-null  object
#  7   NamaFaskes     29157 non-null  object
#  8   LatLongFaskes  29157 non-null  object
#  9   AlamatFaskes   29157 non-null  object
#  10  TelpFaskes     29157 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 2.4+ MB

# %% [markdown]
# # Drop Column

# %%
df = df.drop(['NoLink', 'Link', 'No'], axis=1)
df
# Out:
#                        Provinsi  \
# 0      Nanggroe Aceh Darussalam
# 1      Nanggroe Aceh Darussalam
# 2      Nanggroe Aceh Darussalam
# 3      Nanggroe Aceh Darussalam
# 4      Nanggroe Aceh Darussalam
# ...                         ...
# 29152          Kalimantan Utara
# 29153          Kalimantan Utara
# 29154          Kalimantan Utara
# 29155          Kalimantan Utara
# 29156          Kalimantan Utara
#
#                                                  KotaKab  \
# 0      Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 1      Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 2      Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 3      Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 4      Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# ...                                                  ...
# 29152  Kode Faskes dan Alamat Rumah Sakit BPJS di\r\n...
# 29153  Kode Faskes dan Alamat Rumah Sakit BPJS di\r\n...
# 29154  Kode Faskes dan Alamat Rumah Sakit BPJS di\r\n...
# 29155  Kode Faskes dan Alamat Rumah Sakit BPJS di\r\n...
# 29156  Kode Faskes dan Alamat Rumah Sakit BPJS di\r\n...
#
#                       TipeFaskes KodeFaskes  \
# 0                    Rumah Sakit   0001R001
# 1                    Rumah Sakit   0001R004
# 2                    Rumah Sakit   0105R001
# 3                    Rumah Sakit   0105R013
# 4                      Puskesmas   00010001
# ...                          ...        ...
# 29152  Dokter Praktik Perorangan          -
# 29153                Dokter Gigi          -
# 29154               Klinik Utama          -
# 29155             Klinik Pratama   0472B001
# 29156                     Apotek          -
#
#                                               NamaFaskes  \
# 0      RSU Cut Nyak Dhien\r\n                    \r\n...
# 1      RSU Cut Meutia Langsa\r\n                    \...
# 2      RSUD Langsa\r\n                    \r\n       ...
# 3      RSU Ummi \r\n                    \r\n         ...
# 4      Langsa Lama\r\n                    \r\n       ...
# ...                                                  ...
# 29152                                                  -
# 29153                                                  -
# 29154                                                  -
# 29155  RSUD Akhmad Berahim \r\n                    \r...
# 29156                                                  -
#
#                                         LatLongFaskes  \
# 0      http://maps.google.co.id/?q=4.488058,97.947963
# 1      http://maps.google.co.id/?q=4.488088,97.947781
# 2      http://maps.google.co.id/?q=4.472208,97.975533
# 3      http://maps.google.co.id/?q=4.470376,97.991915
# 4      http://maps.google.co.id/?q=4.478172,97.949988
# ...                                               ...
# 29152                                               -
# 29153                                               -
# 29154                                               -
# 29155                                               -
# 29156                                               -
#
#                        AlamatFaskes               TelpFaskes
# 0        Jl. Tm Bahrum No. 1 Langsa    \r\n 0641-0621039\r\n
# 1       Jl.Garuda Kebun Baru Langsa   \r\n 0641- 4840076\r\n
# 2           Jln.A.Yani No. 1 Langsa      \r\n 0641-22051\r\n
# 3      Jln. Prof. A. Madjid Ibrahim      \r\n 0641-22886\r\n
# 4           Gampong Meurandeh Dayah  \r\n 0641-064121218\r\n
# ...                             ...                      ...
# 29152                             -                        -
# 29153                             -                        -
# 29154                             -                        -
# 29155             Jl. Perintis Km I   \r\n 0813-86928242\r\n
# 29156                             -                        -
#
# [29157 rows x 8 columns]

# %% [markdown]
# # Drop Row `-`

# %%
# print(f'Before drop row {len(df)}')
print(f'Before drop row : {len(df)}')

# Create a list of indexes to drop
listIndex = []
for idx, data in enumerate(df.values.tolist()):
    if '-' in data:
        listIndex.append(idx)

print(f'Invalid data total : {len(listIndex)}')

# Drop rows based on the list of indexes
df.drop(df.index[listIndex], inplace=True)

# Reset the index after dropping rows
df.reset_index(drop=True, inplace=True)

# Print the length of the DataFrame after dropping rows
print(f'After drop row : {len(df)}')
# Out:
# Before drop row : 29157
# Invalid data total : 5415
# After drop row : 23742

# %% [markdown]
# # Filter Tipe Faskes

# %%
print(f'Before filter TipeFaskes {len(df)}')
df = df.query("TipeFaskes != 'Dokter Gigi'")
df = df.query("TipeFaskes != 'Apotek'")
df = df.query("TipeFaskes != 'Dokter Praktik Perorangan'")
print(f'After filter TipeFaskes {len(df)}')
# Out:
# Before filter TipeFaskes 23742
# After filter TipeFaskes 20776

# %% [markdown]
# # Unique Data Per-Column (Explore Untuk Normalisasi) & Cleansing

# %%
df['TipeFaskes'].unique()
# Out:
# array(['Rumah Sakit', 'Puskesmas', 'Klinik Utama', 'Klinik Pratama'],
#       dtype=object)

# %%
df['Provinsi'].unique()
# Out:
# array(['Nanggroe Aceh Darussalam', 'Sumatera Utara', 'Sumatera Barat',
#        'Riau', 'Jambi', 'Sumatera Selatan', 'Bengkulu', 'Lampung',
#        'Kep. Bangka Belitung', 'Dki Jakarta', 'Jawa Barat', 'Jawa Tengah',
#        'D I Yogyakarta', 'Jawa Timur', 'Banten', 'Bali',
#        'Nusa Tenggara Barat', 'Nusa Tenggara Timur', 'Kalimantan Barat',
#        'Kalimantan Tengah', 'Kalimantan Selatan', 'Kalimantan Timur',
#        'Sulawesi Utara', 'Sulawesi Tengah', 'Sulawesi Selatan',
#        'Sulawesi Tenggara', 'Gorontalo', 'Maluku', 'Maluku Utara',
#        'Papua', 'Papua Barat', 'Sulawesi Barat', 'Kepulauan Riau',
#        'Kalimantan Utara'], dtype=object)

# %%
df['KotaKab'] = df['KotaKab'].replace('Kode Faskes dan Alamat Rumah Sakit BPJS', '', regex = True)
df['KotaKab'] = df['KotaKab'].replace('di', '', regex = True)
df['KotaKab'] = df['KotaKab'].replace('\r\n', '', regex = True)
df['KotaKab'] = df['KotaKab'].replace('Kode Faskes dan Alamat Rumah Sakit            BPJS ', '', regex = True)
df['KotaKab'] = df['KotaKab'].replace('    ', ' ', regex = True)
df['KotaKab'] = df['KotaKab'].replace('   ', ' ', regex = True)
df['KotaKab'] = df['KotaKab'].replace('  ', ' ', regex = True)
df['KotaKab'] = df['KotaKab'].apply(lambda x: x.strip())
df['KotaKab'].unique()
# Out:
# array(['Kota Langsa', 'Kab. Gayo Lues', 'Kab. Aceh Selatan',
#        'Kab. Aceh Tenggara', 'Kab. Aceh Timur', 'Kab. Aceh Tengah',
#        'Kab.Aceh Barat', 'Kab. Aceh Besar', 'Kab. Pie',
#        'Kab. Aceh Tamiang', 'Kab. Aceh Utara', 'Kab. Bireun',
#        'Kota Lhokseumawe', 'Kab. Aceh Singkil', 'Kab. Simeulue',
#        'Kota Banda Aceh', 'Kota Sabang', 'Kab. Aceh Jaya',
#        'Kab. Nagan Raya', 'Kab. Aceh Barat Daya', 'Kab. Bener',
#        'Kab. Pie Jaya', 'Kab. Subulussalam', 'Kab. Nias',
#        'Kab. Mandailing Natal', 'Kab. Tapanuli Selatan',
#        'Kab. Tapanuli Tengah', 'Kab. Tapanuli Utara', 'Kab. Toba Samosir',
#        'Kab. Labuhanbatu', 'Kab. Asahan', 'Kab. Simalungun', 'Kab. Dairi',
#        'Kab. Karo', 'Kab. Deli Serdang', 'Kab. Langkat', 'Kota Sibolga',
#        'Kota Tanjung Balai', 'Kota Pematang Siantar',
#        'Kota Tebing Tinggi', 'Kota Medan', 'Kota Binjai',
#        'Kab. Serdang Bedagai', 'Kab. Samosir', 'Kab. Pakpak Bharat',
#        'Kab. Nias Selatan', 'Kab. Humbang Hasundutan',
#        'Kota Padang Sidempuan', 'Kab. Batu Bara',
#        'Kab. Padang Lawas Utara', 'Kab. Padang Lawas',
#        'Kota Gunungsitoli', 'Kab. Nias Utara', 'Kab. Nias Barat',
#        'Kab. Labuhanbatu Utara', 'Kab. Labuhanbatu Selatan',
#        'Kab. Kep Mentawai', 'Kab. Pesisir Selatan', 'Kab Solok',
#        'Kab. Tanah Datar', 'Kab. Padang Pariaman', 'Kab. Agam',
#        'Kab. Lima Puluh Koto', 'Kab. Pasaman', 'Kota Padang',
#        'Kota Solok', 'Kota Sawahlunto', 'Kota Padang Panjang',
#        'Kota Bukittinggi', 'Kota Payakumbuh', 'Kota Pariaman',
#        'Kab. Pasaman Barat', 'Kab. Solok Sel', 'Kab. Dharmasraya',
#        'Kab. Kuantan Singingi', 'Kab. Indragiri Hulu',
#        'Kab. Indragiri Hilir', 'Kab. Pelalawan',
#        'Kab. Siak Sri Indrapura', 'Kab. Kampar', 'Kab. Rokan Hulu',
#        'Kab. Bengkalis', 'Kab. Rokan Hilir', 'Kota Pekan Baru',
#        'Kota Dumai', 'Kab. Meranti', 'Kab. Kerinci', 'Kab. Merangin',
#        'Kab. Sarolangun', 'Kab. Batang Hari', 'Kab. Muara Jambi',
#        'Kab. Tanjab Tim', 'Kab. Tanjab Bar', 'Kab. Tebo', 'Kab. Bungo',
#        'Kota Jambi', 'Kota Sungai Penuh', 'Kab. Ogan Komering Ulu',
#        'Kab. Ogan Komering Hilir', 'Kab. Muara Enim', 'Kab. Lahat',
#        'Kab. Musi Rawas', 'Kab. Musi Banyuasin', 'Kota Lubuk Linggau',
#        'Kota Palembang', 'Kota Prabumulih', 'Kota Pagar Alam',
#        'Kab. Banyuasin', 'Kab. Ogan Ilir', 'Kab. O.K.U Timur',
#        'Kab. O.K.U Selatan', 'Kab. Empat Lawang',
#        'Kab. Penungkalabab L Ilir', 'Kab. Musi Rawas Utara',
#        'Kota Bengkulu Selatan', 'Kab. Rejang Lebong',
#        'Kab. Bengkulu Utara', 'Kota Bengkulu', 'Kab. Muko-Muko',
#        'Kab. Seluma', 'Kab. Kaur', 'Kab. Lebong', 'Kab. Kepahyang',
#        'Kab. Bengkulu Tengah', 'Kab. Lampung Barat', 'Kab. Tanggamus',
#        'Kab. Lampung Selatan', 'Kab. Lampung Timur',
#        'Kab. Lampung Tengah', 'Kab. Lampung Utara', 'Kab. Way Kanan',
#        'Kab. Tulang Bawang', 'Kota Bandar Lampung', 'Kota Metro',
#        'Kab. Pesawaran', 'Kab. Tulang Bawang Barat', 'Kab. Mesuji',
#        'Kab. Pringsewu', 'Kab. Pesisir Barat', 'Kab. Bangka',
#        'Kab. Belitung', 'Kota Pangkal Pinang', 'Kab. Bangka Selatan',
#        'Kab. Bangka Barat', 'Kab. Bangka Tengah', 'Kab. Belitung Timur',
#        'Kota Jakarta Selatan', 'Kota Jakarta Timur', 'Kota Jakarta Pusat',
#        'Kota Jakarta Barat', 'Kota Jakarta Utara', 'Kab. Kep. Seribu',
#        'Kota Cimahi', 'Kota Banjar', 'Kab. Bogor', 'Kab. Sukabumi',
#        'Kab. Cianjur', 'Kab. Bandung', 'Kab. Garut', 'Kab. Tasikmalaya',
#        'Kab. Ciamis', 'Kab. Kuningan', 'Kab. Cirebon', 'Kab. Majalengka',
#        'Kab. Sumedang', 'Kab. Indramayu', 'Kab. Subang',
#        'Kab. Purwakarta', 'Kab. Karawang', 'Kab. Bekasi', 'Kota Bogor',
#        'Kota Sukabumi', 'Kota Bandung', 'Kota Cirebon', 'Kota Bekasi',
#        'Kota Depok', 'Kota Tasikmalaya', 'Kab. Bandung Barat',
#        'Kab. Pangandaran', 'Kab. Cilacap', 'Kab. Banyumas',
#        'Kab. Purbalingga', 'Kab. Banjarnegara', 'Kab. Kebumen',
#        'Kab. Purworejo', 'Kab. Wonosobo', 'Kab. Magelang',
#        'Kab. Boyolali', 'Kab. Klaten', 'Kab. Sukoharjo', 'Kab. Wonogiri',
#        'Kab. Karanganyar', 'Kab. Sragen', 'Kab. Grobogan', 'Kab. Blora',
#        'Kab. Rembang', 'Kab. Pati', 'Kab. Kudus', 'Kab. Jepara',
#        'Kab. Demak', 'Kab. Semarang', 'Kab. Temanggung', 'Kab. Kendal',
#        'Kab. Batang', 'Kab. Pekalongan', 'Kab. Pemalang', 'Kab. Tegal',
#        'Kab. Brebes', 'Kota Magelang', 'Kota Surakarta', 'Kab. Salatiga',
#        'Kota Semarang', 'Kota Pekalongan', 'Kota Tegal',
#        'Kab. Kulon Progo', 'Kab. Bantul', 'Kab. Gunung Kidul',
#        'Kab. Sleman', 'Kota Yogyakarta', 'Kab. Pacitan', 'Kab. Ponorogo',
#        'Kab. Trenggalek', 'Kab. Tulungagung', 'Kab. Blitar', 'Kab. Keri',
#        'Kab. Malang', 'Kab. Lumajang', 'Kab. Jember', 'Kab. Banyuwangi',
#        'Kab. Bondowoso', 'Kab. Situbondo', 'Kab. Probolinggo',
#        'Kab. Pasuruan', 'Kab. Sidoarjo', 'Kab. Mojokerto', 'Kab. Jombang',
#        'Kab. Nganjuk', 'Kab. Maun', 'Kab. Magetan', 'Kab. Ngawi',
#        'Kab. Bojonegoro', 'Kab. Tuban', 'Kab. Lamongan', 'Kab. Gresik',
#        'Kab. Bangkalan', 'Kab. Sampang', 'Kab. Pamekasan', 'Kab. Sumenep',
#        'Kota Keri', 'Kota Blitar', 'Kota Malang', 'Kota Probolinggo',
#        'Kota Pasuruan', 'Kota Mojokerto', 'Kota Maun', 'Kota Surabaya',
#        'Kota Batu', 'Kab. Pandeglang', 'Kab. Lebak', 'Kab. Tangerang',
#        'Kab. Serang', 'Kota Tangerang', 'Kota Cilegon', 'Kota Serang',
#        'Kota Tangerang Selatan', 'Kab. Jembrana', 'Kab. Tabanan',
#        'Kab. Badung', 'Kab. Gianyar', 'Kab. Klungkung', 'Kab. Bangli',
#        'Kab. Karang Asem', 'Kab. Buleleng', 'Kota Denpasar',
#        'Kab. Lombok Barat', 'Kab. Lombok Tengah', 'Kab. Lombok Timur',
#        'Kab. Dompu', 'Kab. Bima', 'Kota Mataram', 'Kab. Sumbawa Besar',
#        'Kota Bima', 'Kab. Sumbawa Barat', 'Kab. Lombok Utara',
#        'Kab. Sumba Barat', 'Kab. Sumba Timur', 'Kab. Kupang',
#        'Kab. T.T.S Soe', 'Kab. T.T.U Kefamenanu', 'Kab. Belu',
#        'Kab. Alor', 'Kab. Lembata', 'Kab. Flores Timur', 'Kab. Sikka',
#        'Kab. Ende', 'Kab. Ngada', 'Kab. Manggarai', 'Kota Kupang',
#        'Kab. Rote-Ndao', 'Kab. Manggarai Barat', 'Kab. Nagekeo',
#        'Kab. Sumba Tengah', 'Kab. Sumba Barat Daya',
#        'Kab. Manggarai Timur', 'Kab. Sabu Raijua', 'Kab. Malaka',
#        'Kota Singkawang', 'Kab. Sambas', 'Kab. Bengkayang', 'Kab. Landak',
#        'Kab. Mempawah', 'Kab. Sanggau', 'Kab. Ketapang', 'Kab. Sintang',
#        'Kab. Kapuas Hulu', 'Kota Pontianak', 'Kab. Melawi',
#        'Kab. Sekadau', 'Kab. Kayong Utara', 'Kab. Kubu Raya',
#        'Kab. Pulang Pisau', 'Kab. Seruyan', 'Kab. Kotawaringin Barat',
#        'Kab. Kotawaringin Timur', 'Kab. Kapuas', 'Kab. Barito Selatan',
#        'Kab. Barito Utara', 'Kab. Sukamara', 'Kab. Lamandau',
#        'Kab. Barito Timur', 'Kab. Katingan', 'Kab. Gunung Mas',
#        'Kab. Murung Raya', 'Kota Palangka Raya', 'Kab. Tanah Laut',
#        'Kab. Kotabaru', 'Kab. Banjar', 'Kab. Barito Kuala', 'Kab. Tapin',
#        'Kab. Hulu Sungai Selatan', 'Kab. Hulu Sungai Tengah',
#        'Kab. Hulu Sungai Utara', 'Kab. Tabalong', 'Kota Banjarmasin',
#        'Kota Banjar Baru', 'Kab. Tanah Bumbu', 'Kab. Balangan',
#        'Kab. Pasir', 'Kab. Pasir Utara', 'Kab. Kutai Barat',
#        'Kab. Kutai Kertanegara', 'Kab. Kutai Timur', 'Kab. Berau',
#        'Kota Balikpapan', 'Kota Samarinda', 'Kota Bontang',
#        'Kab. Mahakam Ulu', 'Kab. Sangirtalaut', 'Kab. Minahasa',
#        'Kab. Sangihe', 'Kab. Boloangmongondow', 'Kota Manado',
#        'Kota Bitung', 'Kab. Minahasa Selatan', 'Kota Tomohon',
#        'Minahasa Utara', 'Kota Kotamobagu', 'Kab. Minahasa Tenggara',
#        'Kode Faskes dan Alamat Rumah Sakit BPJS Kab.Bolaang Mongondow Utr',
#        'Kode Faskes dan Alamat Rumah Sakit BPJS Kab.Kp Siao Tagulandang B',
#        'Kode Faskes dan Alamat Rumah Sakit BPJS Kab.Bolaang Mongondow Slt',
#        'Kode Faskes dan Alamat Rumah Sakit BPJS Kab.Bolaang Mongondow Tmr',
#        'Kab. Parigi Moutong', 'Kab. Banggai', 'Kab. Banggai Kepulauan',
#        'Kab. Morowali', 'Kab. Poso', 'Kab. Donggala', 'Kab. Toli Toli',
#        'Kab. Buol', 'Kota Palu', 'Kab. Tojo Una Una', 'Kab. Sigi',
#        'Kab. Morowali Utara', 'Kab. Banggai Laut', 'Kota Palopo',
#        'Kab. Selayar', 'Kab. Bulukumba', 'Kab. Bantaeng',
#        'Kab. Jeneponto', 'Kab. Takalar', 'Kab. Gowa', 'Kab. Sinjai',
#        'Kab. Maros', 'Kab. Pangkep', 'Kab. Barru', 'Kab. Bone',
#        'Kab. Soppeng', 'Kab. Wajo', 'Kab. Sidenreng Rappang',
#        'Kab. Pinrang', 'Kab. Enrekang', 'Kab. Luwu', 'Kab. Tana Toraja',
#        'Kab. Luwu Utara', 'Kota Makassar', 'Kab. Luwu Timur',
#        'Kab. Toraja Utara', 'Kota Bau-Bau', 'Kab. Buton', 'Kab. Muna',
#        'Kab. Konawe', 'Kab. Kolaka', 'Kota Kendari',
#        'Kab. Konawe Selatan', 'Kab. Kolaka Utara', 'Kab. Wakatobi',
#        'Kab. Bombana', 'Kab. Konawe Utara', 'Kab. Buton Utara',
#        'Kab. Konawe Kepulauan', 'Kab. Kolaka Timur', 'Kab.Muna Barat',
#        'Kab. Buton Tengah', 'Kab. Buton Selatan', 'Kab. Boalemo',
#        'Kab. Gorontalo', 'Kota Gorontalo', 'Kab. Bone Bolango',
#        'Kab. Pohuwato', 'Kab. Gorontalo Utara',
#        'Kode Faskes dan Alamat Rumah Sakit BPJS Kab.Maluku Tenggara Barat',
#        'Kab. Maluku Tenggara', 'Kab. Maluku Tengah', 'Kab. Buru',
#        'Kota Ambon', 'Kab. Seram Bagian Timur', 'Kab. Seram Bagian Barat',
#        'Kab. Kepulauan Aru', 'Kota Tual', 'Kab. Buru Selatan',
#        'Kab. Maluku Barat Daya', 'Kab. Halmahera Tengah', 'Kota Ternate',
#        'Kab. Halmahera Barat', 'Kab. Halmahera Utara',
#        'Kab. Halmahera Selatan', 'Kab. Kepulauan Sula', 'Halmahera Timur',
#        'Kota Tidore Kepulauan', 'Kab. Pulau Morotai',
#        'Kab. Pulau Taliabu', 'Kab. Merauke', 'Kab. Jayawijaya',
#        'Kab. Jayapura', 'Kab. Yapen', 'Kab. Biak Numfor', 'Kab. Paniai',
#        'Kab. Mimika', 'Kota Jayapura', 'Kab. Kerom', 'Kab. Sarmi',
#        'Kab. Puncak Jaya', 'Kab. Pegunungan Bintang', 'Kab. Mapi',
#        'Kab. Asmat', 'Kab. Bouven Digul', 'Kab. Nabire',
#        'Kab. Membramo Raya', 'Kab. Puncak', 'Kab. Fak Fak', 'Kab. Sorong',
#        'Kab. Manokwari', 'Kota Sorong', 'Kab. Sor Sel', 'Kab. Raja Ampat',
#        'Kab. Kaimana', 'Kab. Teluk Bintuni', 'Kab. Teluk Wondama',
#        'Kab. Tambrauw', 'Kab. Maybrat', 'Kab. Pegunungan Arfak',
#        'Kab. Manokwari Selatan', 'Kab. Polewali Mandar', 'Kab. Majene',
#        'Kab. Mamuju', 'Kab. Mamasa', 'Kab. Mamuju Utara',
#        'Kab. Mamuju Tengah', 'Kota Tanjung Pinang', 'Kab. Bintan (Kepri)',
#        'Kab. Tj Balai Karimun', 'Kab. Natuna', 'Kota Batam',
#        'Kab. Lingga', 'Kab. Kep. Anambas', 'Kab. Malinau',
#        'Kab. Bulungan', 'Kab. Nunukan', 'Kota Tarakan',
#        'Kab. Tana Tidung'], dtype=object)

# %%
df['NamaFaskes'] = df['NamaFaskes'].replace('\r\n', '', regex=True)
df['NamaFaskes'] = df['NamaFaskes'].apply(lambda x: x.strip())
df['TelpFaskes'] = df['TelpFaskes'].replace('\r\n', '', regex=True)
df['TelpFaskes'] = df['TelpFaskes'].apply(lambda x: x.strip())
df['Provinsi'] = df['Provinsi'].replace('D I Yogyakarta', 'Daerah Istimewa Yogyakarta')
df['Provinsi'] = df['Provinsi'].replace('Dki Jakarta', 'DKI Jakarta')
df
# Out:
#                        Provinsi           KotaKab      TipeFaskes KodeFaskes  \
# 0      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0001R001
# 1      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0001R004
# 2      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0105R001
# 3      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0105R013
# 4      Nanggroe Aceh Darussalam       Kota Langsa       Puskesmas   00010001
# ...                         ...               ...             ...        ...
# 23734          Kalimantan Utara      Kota Tarakan  Klinik Pratama   0303B003
# 23738          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720101
# 23739          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720102
# 23740          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720103
# 23741          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720104
#
#                   NamaFaskes                                    LatLongFaskes  \
# 0         RSU Cut Nyak Dhien   http://maps.google.co.id/?q=4.488058,97.947963
# 1      RSU Cut Meutia Langsa   http://maps.google.co.id/?q=4.488088,97.947781
# 2                RSUD Langsa   http://maps.google.co.id/?q=4.472208,97.975533
# 3                   RSU Ummi   http://maps.google.co.id/?q=4.470376,97.991915
# 4                Langsa Lama   http://maps.google.co.id/?q=4.478172,97.949988
# ...                      ...                                              ...
# 23734   Klinik Pratama Carsa  http://maps.google.co.id/?q=3.294471,117.590204
# 23738            Tideng Pale  http://maps.google.co.id/?q=3.603225,116.905774
# 23739          Sesayap Hilir  http://maps.google.co.id/?q=3.575481,117.002025
# 23740                Tanalia  http://maps.google.co.id/?q=3.738128,117.568655
# 23741                  Kujau   http://maps.google.co.id/?q=3.492435,117.00118
#
#                        AlamatFaskes      TelpFaskes
# 0        Jl. Tm Bahrum No. 1 Langsa    0641-0621039
# 1       Jl.Garuda Kebun Baru Langsa   0641- 4840076
# 2           Jln.A.Yani No. 1 Langsa      0641-22051
# 3      Jln. Prof. A. Madjid Ibrahim      0641-22886
# 4           Gampong Meurandeh Dayah  0641-064121218
# ...                             ...             ...
# 23734               Sebengkok Tiram  0551-055131457
# 23738       Jl. Kuburan Tideng Pale    0811-5382200
# 23739                Jl. Agis Pulak   0813-45179716
# 23740                       Tanalia   0823-54512125
# 23741             Jl. Trans Kaltara   0813-27082249
#
# [20776 rows x 8 columns]

# %% [markdown]
# # Add Column lat & lng

# %%
detail = df['LatLongFaskes'].str.split('=|,', expand=True).iloc[:, 1:3]
detail = detail.rename(columns={1: 'Latitude', 2: 'Longitude'})
df['lat'] = detail['Latitude']
df['lng'] = detail['Longitude']
df
# Out:
#                        Provinsi           KotaKab      TipeFaskes KodeFaskes  \
# 0      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0001R001
# 1      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0001R004
# 2      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0105R001
# 3      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit   0105R013
# 4      Nanggroe Aceh Darussalam       Kota Langsa       Puskesmas   00010001
# ...                         ...               ...             ...        ...
# 23734          Kalimantan Utara      Kota Tarakan  Klinik Pratama   0303B003
# 23738          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720101
# 23739          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720102
# 23740          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720103
# 23741          Kalimantan Utara  Kab. Tana Tidung       Puskesmas   04720104
#
#                   NamaFaskes                                    LatLongFaskes  \
# 0         RSU Cut Nyak Dhien   http://maps.google.co.id/?q=4.488058,97.947963
# 1      RSU Cut Meutia Langsa   http://maps.google.co.id/?q=4.488088,97.947781
# 2                RSUD Langsa   http://maps.google.co.id/?q=4.472208,97.975533
# 3                   RSU Ummi   http://maps.google.co.id/?q=4.470376,97.991915
# 4                Langsa Lama   http://maps.google.co.id/?q=4.478172,97.949988
# ...                      ...                                              ...
# 23734   Klinik Pratama Carsa  http://maps.google.co.id/?q=3.294471,117.590204
# 23738            Tideng Pale  http://maps.google.co.id/?q=3.603225,116.905774
# 23739          Sesayap Hilir  http://maps.google.co.id/?q=3.575481,117.002025
# 23740                Tanalia  http://maps.google.co.id/?q=3.738128,117.568655
# 23741                  Kujau   http://maps.google.co.id/?q=3.492435,117.00118
#
#                        AlamatFaskes      TelpFaskes       lat         lng
# 0        Jl. Tm Bahrum No. 1 Langsa    0641-0621039  4.488058   97.947963
# 1       Jl.Garuda Kebun Baru Langsa   0641- 4840076  4.488088   97.947781
# 2           Jln.A.Yani No. 1 Langsa      0641-22051  4.472208   97.975533
# 3      Jln. Prof. A. Madjid Ibrahim      0641-22886  4.470376   97.991915
# 4           Gampong Meurandeh Dayah  0641-064121218  4.478172   97.949988
# ...                             ...             ...       ...         ...
# 23734               Sebengkok Tiram  0551-055131457  3.294471  117.590204
# 23738       Jl. Kuburan Tideng Pale    0811-5382200  3.603225  116.905774
# 23739                Jl. Agis Pulak   0813-45179716  3.575481  117.002025
# 23740                       Tanalia   0823-54512125  3.738128  117.568655
# 23741             Jl. Trans Kaltara   0813-27082249  3.492435   117.00118
#
# [20776 rows x 10 columns]

# %% [markdown]
# # Rename Column

# %%
df = df.rename({
  "Provinsi": "province",
  "KotaKab": "city",
  "KodeFaskes": "kode_faskes",
  "NamaFaskes": "facility",
  "LatLongFaskes": "gmap_url",
  "AlamatFaskes": "address",
  "TelpFaskes": "telephone",
  "TipeFaskes": 'type'
}, axis=1)
df
# Out:
#                        province              city            type kode_faskes  \
# 0      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit    0001R001
# 1      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit    0001R004
# 2      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit    0105R001
# 3      Nanggroe Aceh Darussalam       Kota Langsa     Rumah Sakit    0105R013
# 4      Nanggroe Aceh Darussalam       Kota Langsa       Puskesmas    00010001
# ...                         ...               ...             ...         ...
# 23734          Kalimantan Utara      Kota Tarakan  Klinik Pratama    0303B003
# 23738          Kalimantan Utara  Kab. Tana Tidung       Puskesmas    04720101
# 23739          Kalimantan Utara  Kab. Tana Tidung       Puskesmas    04720102
# 23740          Kalimantan Utara  Kab. Tana Tidung       Puskesmas    04720103
# 23741          Kalimantan Utara  Kab. Tana Tidung       Puskesmas    04720104
#
#                     facility                                         gmap_url  \
# 0         RSU Cut Nyak Dhien   http://maps.google.co.id/?q=4.488058,97.947963
# 1      RSU Cut Meutia Langsa   http://maps.google.co.id/?q=4.488088,97.947781
# 2                RSUD Langsa   http://maps.google.co.id/?q=4.472208,97.975533
# 3                   RSU Ummi   http://maps.google.co.id/?q=4.470376,97.991915
# 4                Langsa Lama   http://maps.google.co.id/?q=4.478172,97.949988
# ...                      ...                                              ...
# 23734   Klinik Pratama Carsa  http://maps.google.co.id/?q=3.294471,117.590204
# 23738            Tideng Pale  http://maps.google.co.id/?q=3.603225,116.905774
# 23739          Sesayap Hilir  http://maps.google.co.id/?q=3.575481,117.002025
# 23740                Tanalia  http://maps.google.co.id/?q=3.738128,117.568655
# 23741                  Kujau   http://maps.google.co.id/?q=3.492435,117.00118
#
#                             address       telephone       lat         lng
# 0        Jl. Tm Bahrum No. 1 Langsa    0641-0621039  4.488058   97.947963
# 1       Jl.Garuda Kebun Baru Langsa   0641- 4840076  4.488088   97.947781
# 2           Jln.A.Yani No. 1 Langsa      0641-22051  4.472208   97.975533
# 3      Jln. Prof. A. Madjid Ibrahim      0641-22886  4.470376   97.991915
# 4           Gampong Meurandeh Dayah  0641-064121218  4.478172   97.949988
# ...                             ...             ...       ...         ...
# 23734               Sebengkok Tiram  0551-055131457  3.294471  117.590204
# 23738       Jl. Kuburan Tideng Pale    0811-5382200  3.603225  116.905774
# 23739                Jl. Agis Pulak   0813-45179716  3.575481  117.002025
# 23740                       Tanalia   0823-54512125  3.738128  117.568655
# 23741             Jl. Trans Kaltara   0813-27082249  3.492435   117.00118
#
# [20776 rows x 10 columns]

# %% [markdown]
# # To CSV

# %%
dataProvince = df['province'].unique()
print(dataProvince)
pd.DataFrame({"province": dataProvince}).to_csv("result/provinces.csv", index=False)
print("Success save csv provinces")

dataCity = pd.DataFrame({
  "province": df["province"],
  "city": df["city"]
})


dataCity = dataCity.drop_duplicates(subset=['city'])
print(dataCity)
dataCity.to_csv("result/cities.csv", index=False)
print("Success save csv cities")


dataType = pd.DataFrame({
  "type": df['type'].unique()
})
print(dataType)
pd.DataFrame(dataType).to_csv("result/types.csv", index=False)
print("Success save csv types")

df.to_csv("result/facilities.csv", index=False)
print("Success save csv facilities")
# Out:
# ['Nanggroe Aceh Darussalam' 'Sumatera Utara' 'Sumatera Barat' 'Riau'
#  'Jambi' 'Sumatera Selatan' 'Bengkulu' 'Lampung' 'Kep. Bangka Belitung'
#  'DKI Jakarta' 'Jawa Barat' 'Jawa Tengah' 'Daerah Istimewa Yogyakarta'
#  'Jawa Timur' 'Banten' 'Bali' 'Nusa Tenggara Barat' 'Nusa Tenggara Timur'
#  'Kalimantan Barat' 'Kalimantan Tengah' 'Kalimantan Selatan'
#  'Kalimantan Timur' 'Sulawesi Utara' 'Sulawesi Tengah' 'Sulawesi Selatan'
#  'Sulawesi Tenggara' 'Gorontalo' 'Maluku' 'Maluku Utara' 'Papua'
#  'Papua Barat' 'Sulawesi Barat' 'Kepulauan Riau' 'Kalimantan Utara']
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb Cell 18 line 3
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> dataProvince = df['province'].unique()
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> print(dataProvince)
# ----> <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> pd.DataFrame({"province": dataProvince}).to_csv("result/provinces.csv", index=False)
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=3'>4</a> print("Success save csv provinces")
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=5'>6</a> dataCity = pd.DataFrame({
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=6'>7</a>   "province": df["province"],
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=7'>8</a>   "city": df["city"]
#       <a href='vscode-notebook-cell:/Users/hacktiv8/Documents/Projects/SimpliLife/data-cleaning-kaggle/faskes/data_cleaning.ipynb#X51sZmlsZQ%3D%3D?line=8'>9</a> })
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'result'
